# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarkashish511/COGNITIVE_COMPUTING/blob/main/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

roll_number = 102317239
np.random.seed(roll_number)

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
sales = np.random.randint(1000, 5001, (12, 4))
sales_df = pd.DataFrame(sales, columns=categories, index=months)

# %%
print(sales_df.head())
print(sales_df.describe())
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1666      1674            4849    1747
# Feb         4414      2954            1241    4145
# Mar         4914      3063            3828    2548
# Apr         4774      3715            2274    4197
# May         3679      3573            2529    1803
#        Electronics     Clothing  Home & Kitchen       Sports
# count     12.00000    12.000000        12.00000    12.000000
# mean    4051.00000  2818.416667      3404.25000  2951.500000
# std      971.99364  1279.909688      1327.77525   989.803975
# min     1666.00000  1000.000000      1241.00000  1500.000000
# 25%     3769.00000  1631.750000      2259.00000  2061.000000
# 50%     4347.00000  3008.500000      3924.50000  3110.000000
# 75%     4743.25000  3720.250000      4383.75000  3783.500000
# max     4914.00000  4813.000000      4999.00000  4197.000000

# %%
total_sales_category = sales_df.sum()
print("Total sales per category:\n", total_sales_category)

sales_df_Total_Sales = sales_df.sum(axis=1)
print("Total sales per month:\n", sales_df_Total_Sales)
# Out:
# Total sales per category:
#  Electronics       48612
# Clothing          33821
# Home & Kitchen    40851
# Sports            35418
# dtype: int64
# Total sales per month:
#  Jan     9936
# Feb    12754
# Mar    14353
# Apr    14960
# May    11584
# Jun    17546
# Jul     9509
# Aug    10967
# Sep    12787
# Oct    15718
# Nov    12996
# Dec    15592
# dtype: int64

# %%
average_growth = sales_df.pct_change().mean()
print("\nAverage sales growth between consecutive months for each category:")
print(average_growth)

sales_df_Growth_Rate = sales_df_Total_Sales.pct_change() * 100
# Out:
# Average sales growth between consecutive months for each category:
# Electronics       0.184268
# Clothing          0.386103
# Home & Kitchen    0.246639
# Sports            0.166971
# dtype: float64

# %%
print("Percentage change in Total Sales from the previous month.:\n", sales_df_Growth_Rate)
# Out:
# Percentage change in Total Sales from the previous month.:
#  Jan          NaN
# Feb    28.361514
# Mar    12.537243
# Apr     4.229081
# May   -22.566845
# Jun    51.467541
# Jul   -45.805312
# Aug    15.332843
# Sep    16.595240
# Oct    22.921717
# Nov   -17.317725
# Dec    19.975377
# dtype: float64

# %%
if roll_number % 2 == 0:
    sales_df['Electronics'] *= 0.9
else:
    sales_df['Clothing'] *= 0.85

print("Sales data after discount:")
print(sales_df)
# Out:
# Sales data after discount:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1666   1422.90            4849    1747
# Feb         4414   2510.90            1241    4145
# Mar         4914   2603.55            3828    2548
# Apr         4774   3157.75            2274    4197
# May         3679   3037.05            2529    1803
# Jun         4733   3742.55            4283    4127
# Jul         4148    850.00            2214    2147
# Aug         4798   1279.25            1687    2977
# Sep         2761   1799.45            4240    3669
# Oct         4646   3175.60            4021    3315
# Nov         3799   1077.80            4686    3243
# Dec         4280   4091.05            4999    1500

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sales_df[categories].plot(marker='o')
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales Units")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(7, 5))
sns.boxplot(data=sales_df[categories])
plt.title("Sales Distribution by Category")
plt.show()

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])
print("Element-wise absolute:", np.abs(array))

flattened_array = array.flatten()
print("Percentiles:", np.percentile(flattened_array, [25, 50, 75]))
print("Mean:", np.mean(flattened_array))
print("Median:", np.median(flattened_array))
print("Standard Deviation:", np.std(flattened_array))
# Out:
# Element-wise absolute: [[1 2 3]
#  [4 5 6]]
# Percentiles: [-3.5 -0.5  2.5]
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])
print("floor:", np.floor(a))
print("ceiling:", np.ceil(a))
print("truncated:", np.trunc(a))
print("rounded:", np.round(a))
# Out:
# floor: [-2. -2. -1.  0.  1.  1.  3.]
# ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# truncated: [-1. -1. -0.  0.  1.  1.  3.]
# rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
def swap_lst_elements(lst, idx1, idx2):
    temp = lst[idx1]
    lst[idx1] = lst[idx2]
    lst[idx2] = temp
    return lst

lst = [1, 2, 3, 4, 5]
print("Before Swap:", lst)
print("After Swap:", swap_lst_elements(lst , 1 , 4))
# Out:
# Before Swap: [1, 2, 3, 4, 5]
# After Swap: [1, 5, 3, 4, 2]

# %%
my_set = {5, 15, 25, 35, 45}
my_list = list(my_set)
my_list[2], my_list[3] = my_list[3], my_list[2]
my_set = set(my_list)
print("Modified Set:", my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-28198f1747c8> in <cell line: 0>()
#       1 my_set = {5, 15, 25, 35, 45}
# ----> 2 my_list = list(my_set)
#       3 my_list[2], my_list[3] = my_list[3], my_list[2]
#       4 my_set = set(my_list)
#       5 print("Modified Set:", my_set)
#
# TypeError: 'list' object is not callable
